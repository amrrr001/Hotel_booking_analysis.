# %% [markdown]
# # **Project Name**   - Hotel booking

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Name**            - Pawar Amardeep

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Hotel Business is dependent on the customer traffic they get daily or on occasions. The apex point of this case study is to analyse the data of 2 types of hotels and give complete insights into their past, and current business. Also to provide some envisages that aid their business to grow in the upward direction. I present here my exploratory data analysis, visualizations, interactive plots, animations, and lots of other interesting insights into the Hotel Booking data. I began by examining the raw data and performing the necessary cleaning of the dataset. then determined which features provide the most insight into price prediction and remove those that only serve to add noise. Data visualization and exploratory data analysis were performed on the tidied dataset to inform our modeling. I have tried to get an outlook of the following problem statement using data analytic techniques. Analysis based on the number of bookings. Analysis based on the types of people who book the hotels. Analysis based on price distribution. Analysis based on the type of stay. Analysis based on their arriving and checking out time.I invested a lot of time in discussing and brainstorming ideas - from selecting the dataset to compiling the final version of this report. From EDA, I found that The highest number of bookings was in the year 2016 and the busiest month for the last 2 years (i.e. for the years 2016 and 2017) was the 8th month which is the August month. The highest consumption of meal, by customers is BB (Bed and Breakfast). The optimal length of stay in order to get the best daily rate is 5 days. The Hotels should work on decreasing the booking cancellation ratio? Hotel Owner should work on their Full Board meals, so that the customers having long duration stay can order for The FB(Full Board).

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!**
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyze the data to discover important factors that govern the bookings.
#
# ```
#
# ```
#
#
#
# ```
#
# ```

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Vacations, business stay or a casual trip to a new city, hotel bookings are mandatory and each one of us desires to optimize our stay. Optimization, for someone could be booking a hotel where he/she pays less for a good deal, or maybe just getting the only luxurious suite, in a 7-star hotel during a non-peak period.
#
# We are given a Hotel Booking dataset, which stores tabular information about the guests' booking pattern, stay duration, choice of meal and much more for a consecutive year range and we’ll be performing a profound analysis on the dataset, to dig out details and predict a few trends pertaining to the data. Firstly, I don't want to pay any surged random price for my booking rather, I will be happy to pay an optimized value for my stay. Secondly, I want my vacation to be safe, as I am accompanying my loved ones, so I would prefer a hotel with less crowd and well equipped with health and safety measures.
#
# Our analysis, would be capable of helping prospective guests in choosing the right hotel, right stay duration and much more for their stay and moreover, would also be introspecting for hotel management in bringing out changes (if, any) in their services for the guests.Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# mounting drive, so that I can access the files there
from google.colab import drive
drive.mount ('/content/drive')

# %%
#Load the Dataset
##importing the data set to be analysed
filepath="/content/drive/MyDrive/Dataset/Hotel Bookings.csv"
hotel_df= pd.read_csv(filepath)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
#printing the head of the data which gives us top 5 rows
hotel_df.head()

# %%
hotel_df.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
#verifying the dataset shape before proceeding ahead
#shape gives us count of rows and columns as (rows,columns)
hotel_df.shape

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# Dataset Info :It is used find data type as well as memory usage
hotel_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

hotel_df.duplicated().sum()

# %%
# Dataset Duplicate Value dropping
hotel_df.drop_duplicates(inplace=True)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
#finding out first which columns have null values
#using 'sum' function will show us how many nulls are found in each column of the dataset
hotel_df.isnull().sum().sort_values(ascending=False)

# %%
# Visualizing the missing values
plt.figure(figsize=(18,8))

colours = ['#34495E', 'seagreen']
sns.heatmap(hotel_df.isnull(), cmap=sns.color_palette(colours))

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# In this dataset, there are not too many columns with null(NaN) values, as we can see that children column has only 4 null values And we can also see that country, agent and company columns have null values.
#
# Above Heatmap show the visualiztion of our data also in this we show agent and Company columns highlits more besacuse it has more missing data in it.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
hotel_df.columns

# %%
# Dataset Describe
hotel_df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# Here is information on what these columns represent.
#
# 1.hotel : H1 = Resort Hotel , H2 = City Hotel
#
# 2.is_canceled : If the booking was canceled(1) or not(0)
#
# 3.lead_time : Number of the days that elapsed between the entering date of the booking into the PMS and arrival date
#
# 4.arrival_date_year : Year of arrival date
#
# 5.arrival_date_month : Month of arrival date
#
# 6.arrival_date_week_number : Week number of arrival date
#
# 7.arrival_date_day_of_month : Day of arrival date
#
# 8.stays_in_weekend_nights : Number of Weekned nights(Satuarday or Sunday) the guest stayed or booked to stay at the hotel
#
# 9.stays_in_week_nights : Number of Week nights(Monday to Friday) the guest stayed or booked to stay at the hotel
#
# 10.adults : Number of adults
#
# 11.children : Number of children
#
# 12.babies : Number of babies
#
# 13.meal : Kind of meal opted for
#
# 14.country : Country code
#
# 15.market_segment : Which segement the customer belongs to
#
# 16.distribution_channel : How the customer accesed the stay corporate booking/Direct/TA.TO
#
# 17.is_repeated_guest : Guest comming for first time or not
#
# 18.previous_cancellations : Was their previous cancellations before
#
# 19.previous_bookings_not_canceled : Count of previous booking
#
# 20.reserved_room_type : Type of room reserved
#
# 21.assigned_room_type : Type of room assigned
#
# 22.booking_changes : Count of booking made changes
#
# 23.deposit_type : Deposit type
#
# 24.agent : Booked through agent
#
# 25.company : Type of guest's company
#
# 26.days_in_waiting_list : Number of Days in waiting list
#
# 27.customer_type : Type of customer
#
# 28.adr : Avarage daily rate
#
# 29.required_car_parking_spaces : If car parking is required
#
# 30.total_of_special_requests : Number of additional special requirments
#
# 31.reservation_status : Reservation of status
#
# 32.reservation_status_date : Date of the specific status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
hotel_df['hotel'].unique()

hotel_df['is_canceled'].unique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
##replacing the null values in children column with 0
hotel_df.fillna({'children':0},inplace=True)

# %%
#replacing null country with unknown
hotel_df.fillna({'country':'unknown'},inplace=True)

# %% [markdown]
# In this dataset, there are not too many columns with null(NaN) values, as we can see that children column has only 4 null values which we can replace with 0 because it's quite natural that those people didn't bring any child with them. And we can also see that country, agent and company have null values but these columns can not be dropped as we need these columns for our analysis. Instead, the null countries can be replaced with a string 'unknown'

# %%
#cheking again for null values
hotel_df.isnull().sum()

# %%
print(hotel_df.columns)

# %%
#checking howmany bookings are cancelled and how many are not
hotel_df['is_canceled'].value_counts()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# As we can see that 63371 bookings are cancelled, so we will not be using these 63371 rows for our analysis. Only not cancelled rows will be used for analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
#showing cancelled and non cancelled bookings through pie chart
hotel_df['is_canceled'].value_counts().rename({0:'not cancel',1:'cancelled'}).plot.pie(explode=[0.05,0.05],autopct='%1.1f%%',figsize=(10,8),shadow=True,fontsize=20)
plt.title('Who all canceled their bookings',fontsize=22)
plt.xlabel('')
plt.ylabel('')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As our data cleaning comes to an end we will only be working on those rows where bookings are not cancelled and country is not unknown i chooes pie plot for presenting that percentage ratio of booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here the chart said that their are 73% bookings are not Canceled and 28% are Cancelled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Almost 28% of customers cancelled their bookings. Hotel should implement a cancellation policy, discount on confirmed bookings, and send booking reminders to guests to reduce booking cancellations

# %% [markdown]
# **As our data cleaning comes to an end we will only be working on those rows where bookings are not cancelled and country is not unknown**.

# %%
#obtaining a new dataframe which has cleaned data
hotel_df=hotel_df[(hotel_df['is_canceled']==0) & (hotel_df['country'] != 'unknown')]

# %%
#checking the data frame beforestarting anlysis
hotel_df.info()

# %%
#also checking the 'is_canceled' column
hotel_df['is_canceled'].value_counts()

# %% [markdown]
# **The data is now clean and we can start our analysis**

# %% [markdown]
# #### Chart - 2

# %%
#I am going to use the parent dataframe for this
df_hotel_by_year= hotel_df[['arrival_date_year', 'hotel']].value_counts().groupby('arrival_date_year').sum()

# %%
# Chart - 2 visualization code
plt.rcParams['figure.figsize']= (8,6)
df_hotel_by_year.plot(kind= 'bar', color= ['green', 'orange', 'blue'], fontsize=16)
plt.title('Year-Wise Bookings', fontsize=16)
plt.xlabel('Arrival Year', fontsize=16)
plt.ylabel('Count of Arrival', fontsize=16)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As I given the data for 3 consecutive years starting from 2015, 2016 and 2017. I am just wondering about the percentage of Bookings made each year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most arrivals are observed in the year of 2016 i.e. about 2.5x the previous year.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It also observered a steep fall in the subsequent year. Should be a point of worry for the management

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
#Plotting the arrival count per year 2015,2016,2017 in order
plt.rcParams['figure.figsize']= (10,5)
sns.countplot(data = hotel_df, x = 'arrival_date_year', hue = 'hotel')
plt.title('Count of arrival per year for each hotel ',fontsize=16)
plt.xlabel('Arrival Year', fontsize=16)
plt.ylabel('Count of Arrival', fontsize=16)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose this count plot for visulatizing the overall data,and count of arrival per year for both the Hotels.

# %%
#Plotting arrival count over months
plt.rcParams['figure.figsize']= (15,5)
sns.countplot(data = hotel_df, x = 'arrival_date_month', hue = 'hotel', order= [ 'January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December'])
plt.title('Count of arrival per month each hotel',fontsize=16)
plt.xlabel('Arrival Month', fontsize=16)
plt.ylabel('Count', fontsize=16)

# %%
#Plotting arrival count over months
plt.rcParams['figure.figsize']= (20,5)
sns.countplot(data = hotel_df, x = 'arrival_date_day_of_month', hue = 'hotel')
plt.title('Count of arrival per day for each hotel', fontsize = 16)
plt.xlabel('Arrival Date', fontsize=16)
plt.ylabel('Count', fontsize=16)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Month of August saw major footfalls/arrivals in either of the hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Days of the month have no such trend in the arrivals.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
plt.rcParams['figure.figsize']= (20,5)
sns.countplot(data = hotel_df, x = 'stays_in_weekend_nights')
plt.title('Count of stays on weekend nights', fontsize=16)
plt.xlabel('Stays in weekend nights', fontsize=16)
plt.ylabel('Count', fontsize=16)
plt.xlim(0.5,20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Analyse some more data in the columns of weekend and weekday stays.

# %%
#let's also trying plotting a distribution plot and see which gives better details
#use countplot for weekend nights
sns.histplot(hotel_df, x = hotel_df['stays_in_weekend_nights'], bins=[1, 2, 3, 4, 5, 6, 7])
plt.title('Count of stays on weekend nights', fontsize=16)
plt.xlabel('Stays in weekend nights', fontsize=16)
plt.ylabel('Density of count', fontsize=16)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The density of count is high at values 1 and 2, hence most people arrived/stayed for 1 or 2 weekends nights and fewer for more weekend nights.
#
# I like the countplot more than the histplot, we might try to use it later.

# %%
#use countplot for week night
plt.rcParams['figure.figsize']= (20,5)
sns.countplot(data = hotel_df, x = 'stays_in_week_nights')
plt.title('Count of stays on week nights', fontsize=16)
plt.xlabel('Stays in week nights', fontsize=16)
plt.ylabel('Count', fontsize=16)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Finally, we have got something, It was hiding too deep.We can culminate that the arrival of guests is more on week days nights than in weekends nights.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#identifying adults count from the data
df_adults= hotel_df[['hotel','adults']][hotel_df['adults']>0].groupby(['hotel']).count()
df_adults

# %%
#Visualisation of adults
plt.rcParams['figure.figsize']= (20,5)
sns.countplot(data = hotel_df, x= 'adults', hue= 'hotel').set_title('Count of adults')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Explore the category of guest Adult in each hotel. This will help us tagging each hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Majorty of the guests come in couple as we can see from count of adults plot, both the hotels acheive peak at 2.0

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# spoecifically City Resort could be tagged as a "Duo/Couple-Friendly Hotel"
#
# **Note: Two people together can be a couple i.e M+F or they can be just two people checked-in together so, irrespective of their gender they can be called a Duo.**

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
#identifying children count from the data
df_children= hotel_df[['hotel','children']][hotel_df['children']>0].groupby(['hotel']).count()
df_children

# %%
#Visualisation of children
plt.rcParams['figure.figsize']= (20,5)
sns.countplot(data = hotel_df, x= 'children', hue= 'hotel').set_title('Count of children')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Explore the category of guest children in each hotel. This will help us tagging each hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Guests bringing children with them have more preference to City Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# City Hotel could also be tagged as a "Children-Friendly Hotel"

# %%
# Visualization of babies
plt.rcParams['figure.figsize']= (20,5)
sns.countplot(data = hotel_df, x= 'babies', hue= 'hotel').set_title('Count of babies')

# %% [markdown]
# 1. Why did you pick the specific chart?
#
# Explore the category of guest Babies in each hotel. This will help us tagging each hotel.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart
#
# Guests bringing babies with them have no such preference over Hotels, but a bit more towards Resort Hotel

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
#
# Resort Hotel could be tagged as "Babies-Friendly Hotel"

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
#use countplot for diposit type
plt.rcParams['figure.figsize']= 5,5
sns.countplot(data = hotel_df, x = 'deposit_type')
plt.title('Types of deposits', fontsize = 14)
plt.xlabel('Type of Deposit', fontsize = 12)
plt.ylabel('Count of Guests', fontsize = 12)

# %%
#let's also check the 'No Deposit' bookings by Hotel
hotel_df[['deposit_type', 'hotel']][hotel_df['deposit_type']=='No Deposit'].groupby('hotel').count()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick this count plot for checking deposit type. If we quickly gauge by observation then Percentage of 'No Deposit' over Total Bookings for Resort Hotel is more than City Hotel .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see, that most of the guests preferred booking with No Deposit.A few with Non-refundable deposit and a very few with Refundable Deposit. The people opting for Non-Refundable Deposit, what do you think why would they choose this risky option as in case of any urgency, they might have to cancel their bookings and they will not be eligible for their deposit amount. Are they so sure about the travel plan

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Customers do not want to pay a pre-deposit for a reservation. Hotels should promote advance deposits because not only does an advance deposit allow you to recognize revenue faster, it also greatly decreases the risk of cancellations

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
#Creating the visualisation using the countplot
plt.rcParams['figure.figsize']= (5,5)
sns.countplot(data = hotel_df, x = 'is_repeated_guest')
plt.title('Graph showing whether guest is repeated guest', fontsize = 10)

# %%
hotel_df[['hotel', 'is_repeated_guest']][hotel_df['is_repeated_guest']==1].groupby(['hotel']).count()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In the above graph,I show the no of Repeated and not repeated guest to analize such ratio i pick count plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# In the above graph, 0 is not-repeated and 1 is repeated, therefore, we can culminate that there are a very few guests who are repeated, and mostly are non-repeated or the first time guests

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# This data output shall be considered at the priority by the Management Team. There might be some Service and/or Marketing tactic that can help the hotels to increase their repeated guests.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

#We firstly need total stay duration of the guests including stays in weekends and week Snights.
hotel_df['total_night_stays'] = hotel_df['stays_in_weekend_nights']+ hotel_df['stays_in_week_nights']
#getting back to our seaborn plot
sns.countplot(x=hotel_df['total_night_stays'])
plt.xlim(0.5,20)
plt.title('Nights spent by guests(Till 20 Nights)')
plt.xlabel('No. of Nights', fontsize=16)
plt.ylabel('Count', fontsize=16)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# As we know our guests let's see their duration of stay, so that we can know the optimal stay duration in overall and by each hotel as well

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# We can clearly see that most of the guests (comprises of almost 80 percent of the guests) stayed for 1,2,3,4 and 5 nights.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# Hotel management team can provide more services for impruving their stay duration.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
#use countplot to find duration of stay for both hotel
plt.rcParams['figure.figsize']= 10,5
sns.countplot(data=hotel_df, x= 'total_night_stays', hue= 'hotel')
plt.xlim(0.5,20)
plt.title('Hotel-wise Nights spent by guests (Till 20 Nights)')
plt.xlabel('No. of Nights', fontsize=16)
plt.ylabel('Count', fontsize=16)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# find the duration of stay for each hotel.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# For City Hotel, most of their guests stayed back for 2 or 3 days.
#
# For Resort Hotel, most of their guests stayed back for 1 or 7 days.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# City Hotel are not so busy compaired to Resort hotel so City hotel may lead to negetive groth.

# %% [markdown]
# #### Chart - 11

# %%
#We just have to select all the values of special requests which are greater than 0, i.e. when atleast one request has been made.
#using groupby by hotel, we can easily count them
df_special_requests_hotel_wise= hotel_df[['hotel', 'total_of_special_requests']][hotel_df['total_of_special_requests']>0].groupby('hotel').count()

# %%
# Chart - 11 visualization code
#to check hotel wise performance of special req. by pie plot
plt.rcParams['figure.figsize']= 6,6
df_special_requests_hotel_wise.plot(kind='pie', autopct='%.0f%%', fontsize= 14, subplots= True)
plt.title('Hotel-wise Percentage of Special requests')
plt.ylabel(' ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Hotel wise Performance of Special Request I choose pie plot that can give Percentage of it.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The City Hotel guests made a total of 62 percentage of total special requests while The Resort Hotel guests made only 38 percent of the total.But, as we earlier saw the total number of guests are also in a similar ratio as the requests, so it might not yield a valuable output.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# However, City Hotel staff can expect more special requests by their guests than the Resort Hotel staff.

# %% [markdown]
# **Determining the price for each customer.**

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#define custom function for price
def price(a,b):
  return a*b
hotel_df['price']=hotel_df.apply(lambda x1:price(x1['adr'],x1['total_night_stays']),axis=1)

# %%
hotel_df[['price','adr','total_night_stays']].head(15)

# %%
#use lineplot for revenue earned by hotels yearly
plt.figure(figsize=(24,9))
sns.lineplot(x='arrival_date_month',y='price',data=hotel_df,hue='arrival_date_year',palette='Dark2')
plt.title('Revenue earned by hotels for each year',fontsize=20)
plt.xlabel('Nights Stayed',fontsize=15)
plt.ylabel('Price',fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# From this line plot we can saw Revenue earned by hotels for each year

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As per above lineplot I saw that Revenue earned by hotels for 2016 and 2017 is highest and the busiest month is 8th (i.e. August) .

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Hotel should work on their revenue for all seasion

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
#use countplot for type of meal preferred
plt.figure(figsize=(20,5))
sns.countplot(x=hotel_df['meal'])
plt.title('Preferred Meal type')
plt.xlabel('Type of meal required in hotel')
plt.ylabel('count')

# %%
hotel_df['meal'].value_counts(normalize=True)

# %%
#use pieplot for meal disribution
hotel_df['meal'].value_counts().plot.pie(explode=(0.03,0.03,0.03,0.01,0.001),autopct='%1.01f%%',shadow=False,figsize=(9,10),fontsize=10,labels=None)
plt.title("% Distribution of meal",fontsize=20)
labels=hotel_df['meal'].value_counts().index.tolist()
plt.legend(bbox_to_anchor=(0.85, 1),loc='upper left', labels=labels)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The count plot show the different type of food is provided by hotel.
#
# As well as pie plot we show the percentage distribution of meal.
#
# Type of meal BB(bed and breakfast)=78.7%
#
# FB(full board) breakfast+lunch+dinner+other meal=0.4%
#
# HB(half board) brekfast+diner =10.5%
#
# SC(self catering) = 9.7%
#
# undefied = 0.6%

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart I found that the most prefferd meal by the customer is BB(Bed and Breakfast)

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The hotel Management Team should work on thier avilability of meal type they can serve FB for attarct their Guests.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
#creating a new Dataset
#creating a new Dataset
new_df=hotel_df[['lead_time','arrival_date_year','arrival_date_week_number','arrival_date_day_of_month','stays_in_weekend_nights','stays_in_week_nights','adults','children','babies','is_repeated_guest','previous_cancellations','previous_bookings_not_canceled','booking_changes','days_in_waiting_list','adr','required_car_parking_spaces','total_of_special_requests','total_night_stays','price' ]]

# %%
plt.rcParams['figure.figsize']= 20,10
sns.heatmap(new_df.corr(), cmap= 'coolwarm' ,annot=True);

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I use Heatmap for Multivarient Analysis to check corelation between multiple variables

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Focus on total_night_stays & stays_in_weekend_nights and total_night_stays & stays_in_week_nights . Here we can again verify that,stay in week was more than the weekends as total night stays!!

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Plotting pair plot for dataset
plt.figure(figsize=(20,15))
ax=sns.pairplot(hotel_df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick this pair plot for multiple varriable analysis

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can conclude from the relationship between lead_time and is_canceled that a longer lead time does not result in cancellations. We can conclude from the lead_time and arrival_date_year graphs that people were consistently interested in booking rooms in advance in 2015, 2016, and 2017.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Explain Briefly.
#
# A city hotel has more bookings than a resort. Offer packages and promotions to promote bookings for the resort hotel.
#
# BB is the most requested food. The hotel should maintain food quality while also offering discounts on other foods to promote other food types, reducing the burden on kitchen management and keeping a variety of food options available to customers.
#
# Very few customers visited again. So hotels can increase repeat bookings by offering the right repeat booking incentives, understanding the motivations behind repeat bookings, marketing to your guests’ past interests, and assessing past bookings to identify priority guests.
#
# People typically book rooms for two people, so encourage family and group bookings. You can maximize revenue by promoting it with a discounted offer for group bookings.
#
# City Hotel's most of guests stayed back for 2 or 3 days compaired to Resort Hotel's most of their guests stayed back for 1 or 7 days.
#
# We can culminate that the arrival of guests is more on week days nights than in weekends nights.
#
# As I given the data for 3 consecutive years starting from 2015, 2016 and 2017. I am just wondering about the percentage of Bookings made each year.
#
# Most arrivals are observed in the year of 2016 i.e. about 2.5x the previous year.
#
# Explore the category of guest Adults,Children,Babies in each hotel. here ,I found which hotel Customers do not want to pay a pre-deposit for a reservation. Hotels should promote advance deposits because not only does an advance deposit allow you to recognize revenue faster, it also greatly decreases the risk of cancellations.will safe for all categories . Majorty of the guests come in couple both the hotels acheive peak at 2.0.Guests bringing children with them have more preference to City Hotel.as well as both categories of guest city hotel have lilttle bit more preference for babies.
#
# Customers do not want to pay a pre-deposit for a reservation. Hotels should promote advance deposits because not only does an advance deposit allow you to recognize revenue faster, it also greatly decreases the risk of cancellations.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# City Hotel is the most booked hotel with 73 percent not_canceled bookings.
# Resort Hotel is preferred over City Hotel by Adults and childrens.
# Resort Hotel has been preferred over City Hotel by larger group of guests or families.
# City Hotel canceled bookings is almost thrice the canceled booking of Resort Hotel. This might be due to no cancelation charges or no-deposit booking allowed by them.
# Year 2016 observed most number of Bookings for the Hotels cumulatively.
# Month of August saw most number of arrivals in either of the hotels. So, if you want to be accompanied by a large number of co-guests then choose August for your visit.
# Also, guests are observed to be spending more week nights than weekend nights.
# City Resort could be tagged as a "Duo/Couple-Friendly Hotel" & "Children-Friendly Hotel". Whereas, Resort Hotel could be tagged as "Babies-Friendly Hotel"
# There are very few repeated guests in each hotels.
# For City Hotel, most of their guests stayed back for 2 or 3 days.For Resort Hotel, most of their guests stayed back for 1 or 7 days.
# The City Hotel guests made a total of 64 percentage of total special requests while The Resort Hotel guests made only 36 percent of the total.
# City Hotel allows more No Deposit Bookings in count than Resort Hotel. But, the Percentage of No Deposit Bookings over total bookings is higher for Resort Hotel.
# The price variance and standard deviation for City Hotel is lower than Resort Hotel. The prices of Resort Hotel are more than City Hotel in the months of July, August,September and June. For rest of the months, Prices of City Hotel are consistently higher than Resort Hotel.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
